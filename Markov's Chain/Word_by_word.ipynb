# %% [markdown]
# <a href="https://colab.research.google.com/github/legendarygirl56/Data-science/blob/master/Markov's%20Chain/Word_by_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk #natural lang tool kit used for english words modifications

# %%
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# ...

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
sent ="My name is Ms. Ayushi Doshi. And I am a strong girl."

# %%
sent_tokenize(sent)
# Out:
# ['My name is Ms. Ayushi Doshi.', 'And I am a strong girl.']

# %%
word_tokenize(sent)
# Out:
# ['My',
#  'name',
#  'is',
#  'Ms.',
#  'Ayushi',
#  'Doshi',
#  '.',
#  'And',
#  'I',
#  'am',
#  'a',
#  'strong',
#  'girl',
#  '.']

# %%
line="1, 3, 5, 7, 9"

# %%
line2="1,3,5, 7, 9"

# %%
word_tokenize(line)
# Out:
# ['1', ',', '3', ',', '5', ',', '7', ',', '9']

# %%
word_tokenize(line2)
# Out:
# ['1,3,5', ',', '7', ',', '9']

# %%
import requests
import random

# %%
url="https://cb.lk/speech"

# %%
data=requests.get(url)

# %%
text=data.text

# %%
words=word_tokenize(text)

# %%
k=3

# %%
probabs={}
for i in range(k, len(words)):
  present=tuple(words[i-k:i])
  future=words[i]

  if present not in probabs:
    probabs[present]={}

  if future not in probabs[present]:
    probabs[present][future]=0

  probabs[present][future]+=1

# %%
probabs
# Out:
# {('26', '8', '2016'): {',': 1},
#  ('8', '2016', ','): {'Afghanistan': 1, 'India': 3},
#  ('2016', ',', 'India'): {'All': 1,
#   'Economics': 1,
#   'Global': 1,
#   'Golden': 1,
#   'Inauguration': 1,
#   'Independence': 1,
#   'Indian': 1,
#   'International': 3,
#   'Joint': 1,
#   'MOF': 1,
#   'Make': 1,
#   'Mann': 4,
#   'Maritime': 1,
#   'Meeting': 1,
#   'Niti': 1,
#   'North': 1,
#   'Pradhan': 1,
#   'Railway': 1,
#   'Remarks': 1,
#   'South': 1,
#   'Tiger': 1,
#   'Unveils': 1,
#   'plenary': 1},
#  (',', 'India', 'Niti'): {'Aayog': 1},
#  ('India', 'Niti', 'Aayog'): {'There': 1},
#  ('Niti', 'Aayog', 'There'): {'was': 1},
#  ('Aayog', 'There', 'was'): {'a': 1},
#  ('There', 'was', 'a'): {'Cabinet': 1,
#   'Gandhi': 1,
#   'Polo': 1,
#   'certain': 1,
#   'doctor': 1,
#   'task': 1,
#   'tendency': 3,
#   'time': 16},
#  ('was', 'a', 'time'): {',': 1, 'in': 1, 'when': 20},
#  ('a', 'time', 'when'): {',': 1,
#   'Government': 1,
#   'a': 2,
#   'about': 1,
# ...

# %%
start_loc=random.randint(1000,2000)

# %%
seed = words[start_loc:start_loc+10]

# %%
seed
# Out:
# ['Two',
#  'way',
#  'trade',
#  'has',
#  'grownby',
#  'over',
#  '300',
#  'percent',
#  'in',
#  'last']

# %%
for i in range(500):
  present = tuple(seed[-k:])
  possib = probabs[present]
  top_items=2
  top=sorted(possib.items(), key=lambda item: item[1])[-top_items:]
  future = random.choice(top)[0]
  seed=seed+[future]

# %%
" ".join(seed)
# Out:
# "Two way trade has grownby over 300 percent in last ten years , we have launched the Start up India , Stand Up India . The world has accepted , what world has given to the tune of approximately four hundred rupees per cylinder . This subsidy was being provided to rich and poor alike . We decided to find out as to when were they started . I clearly believe that these ever changing desires are called whims by the people . We have also agreed to enhance our exercises in the coming years . I have been saying that the 21st century has . We will work to ensure a safe , sustainable , habitable cities to cater to its growing urban population . It is a great pleasure to welcome President Putin to reform regulations so that Russian jewellery makers can send their rough diamond to India and partake in the benefits of the industrial development . India is a land of immense opportunities . Fifty of our cities and our people closer and facilitates enhanced science , education , skills , systems in
# ...
