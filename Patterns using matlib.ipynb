# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
arr=np.empty((100,100))

# %%
arr
# Out:
# array([[1.92657223e-316, 6.55409858e-316, 2.12199579e-314, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        ...,
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000],
#        [0.00000000e+000, 0.00000000e+000, 0.00000000e+000, ...,
#         0.00000000e+000, 0.00000000e+000, 0.00000000e+000]])

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i+j)%100
plt.imshow(arr)

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i+j)%100
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i+j)%10
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i+j)
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i*i+j*j)%100
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i*i+j*j)%10
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i*i+j*j)%100
plt.imshow(arr)

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i*i*i+j*j*j)%10
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i*i+j*j)%1000
plt.imshow(arr,cmap="gray")

# %%
for i in range(100):
    for j in range(100):
        arr[i,j]=(i*i+j*j)%10000
plt.imshow(arr,cmap="gray")

# %%
a = np.zeros((10,10))

# %%
plt.imshow(a,cmap="gray")

# %%
a[:4, :4]=1

# %%
plt.imshow(a,cmap="gray")

# %%
a[-4:,-4:]=1

# %%
plt.imshow(a,cmap="gray")

# %%
a[4:-4,4:-4]=0.5

# %%
plt.imshow(a,cmap="gray")
